# %%
array = []
for i in range(0,500,6):
    array.append(i)
print array
# Out:
# [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 126, 132, 138, 144, 150, 156, 162, 168, 174, 180, 186, 192, 198, 204, 210, 216, 222, 228, 234, 240, 246, 252, 258, 264, 270, 276, 282, 288, 294, 300, 306, 312, 318, 324, 330, 336, 342, 348, 354, 360, 366, 372, 378, 384, 390, 396, 402, 408, 414, 420, 426, 432, 438, 444, 450, 456, 462, 468, 474, 480, 486, 492, 498]

# %%
def binary_search(array, element, low = 0, high = len(array)):
    
    mid = (low+high)/2
    
    if(array[mid] > element):
    	print "%i > %i" %(array[mid], element)
        return binary_search(array, element, low, (high+low)/2)
    elif(array[mid] < element):
    	print "%i < %i" %(array[mid], element)
        return binary_search(array, element, (high+low)/2, high)
    elif(array[mid] == element):
        return mid
    return -1

# %%
binary_search(array, 347)
# Out:
# 252 < 347
# 378 > 347
# 312 < 347
# 342 < 347
# 360 > 347
# 348 > 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# 342 < 347
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-15b522ff983a> in <module>()
# ----> 1 binary_search(array, 347)
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       5     if(array[mid] > element):
#       6         print "%i > %i" %(array[mid], element)
# ----> 7         return binary_search(array, element, low, (high+low)/2)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       5     if(array[mid] > element):
#       6         print "%i > %i" %(array[mid], element)
# ----> 7         return binary_search(array, element, low, (high+low)/2)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       5     if(array[mid] > element):
#       6         print "%i > %i" %(array[mid], element)
# ----> 7         return binary_search(array, element, low, (high+low)/2)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
# ...
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       8     elif(array[mid] < element):
#       9         print "%i < %i" %(array[mid], element)
# ---> 10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#      12         return mid
#
# <ipython-input-35-1031492a608e> in binary_search(array, element, low, high)
#       7         return binary_search(array, element, low, (high+low)/2)
#       8     elif(array[mid] < element):
# ----> 9         print "%i < %i" %(array[mid], element)
#      10         return binary_search(array, element, (high+low)/2, high)
#      11     elif(array[mid] == element):
#
# /Users/jeremynixon/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.pyc in write(self, string)
#     210         else:
#     211             # Make sure that we're handling unicode
# --> 212             if not isinstance(string, unicode_type):
#     213                 string = string.decode(self.encoding, 'replace')
#     214
#
# RuntimeError: maximum recursion depth exceeded while calling a Python object
